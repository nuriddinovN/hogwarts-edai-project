# %%
import pandas as pd

features = [
    'Architecture',
    'Special strength',
    'GPU usage',
    'Prompt Tuning Support',
    'Speed & Efficiency',
    'Multilingual Support',
    'Use Case'
]

AI_models = {
    'FlanT5base': [
        'Encoder-decoder Transformer (T5ForConditionalGeneration)',
        'Instruction-tuned; understands tasks directly from prompts',
        'Moderate — ~2GB VRAM; slower than decoder-only models',
        'Yes — supports LoRA, Prefix Tuning via PEFT',
        'Good efficiency; ~1–2s per task on GPU',
        'Decent — handles multiple languages; English strongest',
        'Summarization, Q&A, classification, translation, reasoning'
    ],
    'Bart': [
        'Encoder-decoder Transformer',
        'Denoising autoencoder; strong for summarization and reconstruction',
        'Moderate — requires 8GB+ VRAM',
        'Limited — less support for modern prompt tuning methods',
        'Moderate — slower compared to decoder-only models',
        'Mostly English (multilingual versions exist)',
        'Summarization, text generation, sentence reconstruction'
    ],
    'Mistral7B': [
        'Decoder-only Transformer (GPT-style)',
        'High performance for its size; efficient and open-source',
        'High — needs 16GB+ VRAM or multiple GPUs',
        'Limited — can be fine-tuned via LoRA / QLoRA',
        'Very fast — optimized with FlashAttention-2',
        'Strong — trained on multilingual datasets',
        'Chatbots, code generation, Q&A, general-purpose text generation'
    ],
    'LLaMA2': [
        'Decoder-only Transformer',
        'Strong general-purpose performance in smaller parameter sizes',
        'High — ~16GB VRAM for 7B model, more for larger ones',
        'Yes — supports LoRA, QLoRA, and other PEFT methods',
        'Fast — designed for efficient inference',
        'Good — trained on multilingual data',
        'Chatbots, reasoning, text generation, coding'
    ]
}

df = pd.DataFrame(AI_models, index=features)
df
# Out:
#                                                               FlanT5base  \
# Architecture                                 Encoder-decoder Transformer
# Special strength       Instruction tuning; performs well on diverse N...
# GPU usage              Moderate — runs on 8GB VRAM but slower than de...
# Prompt Tuning Support  Yes — supports prompt tuning like LoRA and pre...
# Speed & Efficiency        Efficient, but slower than decoder-only models
# Multilingual Support   Decent — supports multiple languages, English ...
# Use Case               Text generation, Q&A, translation, summarizati...
#
#                                                                     Bart  \
# Architecture                                 Encoder-decoder Transformer
# Special strength       Denoising autoencoder; strong for summarizatio...
# GPU usage                                  Moderate — requires 8GB+ VRAM
# Prompt Tuning Support  Limited — less support for modern prompt tunin...
# ...
